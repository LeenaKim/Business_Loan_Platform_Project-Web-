# %% [markdown]
# # 기업 고유번호 불러오기

# %% [markdown]
# ## 회사의 고유번호 데이터를 불러오는 작업

# %%
openApi = "ab851319407812ac10d593dcb2fef51d0c944b66"

# %%
### 필요한 모듈
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile

### 회사고유번호 데이터 불러오기
url = 'https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=' + openApi
with urlopen(url) as zipresp:
    with ZipFile(BytesIO(zipresp.read())) as zfile:
        zfile.extractall('corp_num')

# %% [markdown]
# ## XML 데이터 읽기

# %%
### 모듈 import
import xml.etree.ElementTree as ET

### 압축파일 안의 xml 파일 읽기
tree = ET.parse('CORPCODE.xml')
root = tree.getroot()
    ## 총 80939개 기업

# %% [markdown]
# ## 필요한 정보를 얻기위한 함수 만들기

# %%
### 회사 이름으로 회사 고유번호 찾기
def find_corp_num(find_name):
    for country in root.iter("list"):
        if country.findtext("corp_name") == find_name:
            return country.findtext("corp_code")

# %%
find_corp_num('삼성전자')

# %%
corp_code = []

for country in root.iter("list"):
    corp_code.append(country.findtext("corp_code"))

# %%
print(corp_code)

# %%
len(corp_code)

# %% [markdown]
# # 기업개황api

# %% [markdown]
# ## 한 회사 검색 테스트

# %%
import requests
import pandas as pd
from urllib.request import urlopen
from time import sleep
import time

# %%
url = "https://opendart.fss.or.kr/api/company.json?crtfc_key=" + crtfc_key_2 + "&corp_code=00126380"
response = requests.get(url)
print(response.text)
#urldata = response.json()
#corp_df = pd.DataFrame(urldata, index=[0])
# Out:
# {"status":"000","message":"정상","corp_code":"00126380","corp_name":"삼성전자(주)","corp_name_eng":"SAMSUNG ELECTRONICS CO,.LTD","stock_name":"삼성전자","stock_code":"005930","ceo_nm":"김기남, 김현석, 고동진","corp_cls":"Y","jurir_no":"1301110006246","bizr_no":"1248100998","adres":"경기도 수원시 영통구  삼성로 129 (매탄동)","hm_url":"www.sec.co.kr","ir_url":"","phn_no":"031-200-1114","fax_no":"031-200-7538","induty_code":"264","est_dt":"19690113","acc_mt":"12"}

# %%
print(response)
# response에 200이 나오면 잘 응답이 온것. 400은 잘 응답이 안온것.

# %% [markdown]
# ## 모든 기업 개황 검색해 데이터프레임화 후 저장

# %% [markdown]
# ### 회사 고유번호 불러오기 (Load 또는 Read)

# %%
### xml 모듈 import
import xml.etree.ElementTree as ET

### xml 파일 읽기
tree = ET.parse('CORPCODE.xml')
root = tree.getroot()

# %% [markdown]
# ### 기업 고유번호 모음 list 만들기

# %%
### 기업 고유번호 모음 list 만들기
code_list=[]
for country in root.iter("corp_code"):
    code_list.append(country.text)

# %%
print(code_list[0:3])
# Out:
# ['00434003', '00434456', '00430964']

# %% [markdown]
# ### 기업 개황 검색 함수 만들기

# %%
### 본인의 인증키 입력
crtfc_key_1 = "ab851319407812ac10d593dcb2fef51d0c944b66"
crtfc_key_2 = "f494a3020128060351c817cabf5b1b4a851e0737"
crtfc_key_3 = "5a79f1c6d673e00b0614c74e542b390ddd0b3542" 
crtfc_key_4 = "614f7fe579f14daf0ecb6aa38652677ab0576191"
crtfc_key_5 = "d4857d7491b5c47d494584350731c06dc7b66882" 
crtfc_key_6 = "bb7d92cbd78b6b67d156bef779a02e74bce661c4"
crtfc_key_7 = "a30987f4b05d0371f9f3d84c898efc698bbbc1e2"
crtfc_key_8 = "012be8cea16c0d414c5273f7422280f3f9905adf"
crtfc_key_9 = "ba2c91d2cc13f79700da1e0ed1542d2a37f18068"
crtfc_key_10 = "02c190bf4a27db86defd39afd0c48183dbff1d2c"

# %%
crtfc_key_11 = "a263608b5e4e9040a9de7ad1f0ff62808b29503d"
crtfc_key_12 = "c42daf7eaba42a0ed786b61e59240c58caa1d5d6"

# %%
### 기업개황 검색 함수 만들기
def load_data(corp_code):
    
    ### 기업개황 요청 url
    url = "https://opendart.fss.or.kr/api/company.json?crtfc_key=" +crtfc_key_1+"&corp_code=" +corp_code

    ### HTTP 요청
    r = requests.get(url)
     
    ### 요청한 데이터는 json형태이기 때문에 json으로 읽어줍니다.
    company_data = r.json()

    ### 기업개황을 요청했을 때 기업개황에 대한 자료를 반환합니다.
    return company_data

# %%
print(r)

# %% [markdown]
# ### 반복문을 통한 데이터 수집

# %%
### 데이터를 담아둘 list 생성
company_list_1 = [] # company_list_1 0 ~ 9,000 (ㅇ)
company_list_2 = [] # company_list_2 9,000 ~ 18,000 (ㅇ) 

company_list_4 = [] # company_list_4 18,000 ~ 27,000 (ㅇ)
company_list_5 = [] # company_list_5 27,000 ~ 36,000 (ㅇ)
company_list_6 = [] # company_list_6 36,000 ~ 45,000 (ㅇ)
company_list_7 = [] # company_list_7 45,000 ~ 54,000 (ㅇ)
company_list_8 = [] # company_list_8 54,000 ~ 63,000 (ㅇ)
company_list_9 = [] # company_list_9 63,000 ~ 72,000 (ㅇ)
company_list_10 = [] # company_list_10 72,000 ~ 80,939 (ㅇ)

# %%
company_list_4 = []

# %%
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00333148', 'corp_name': '(주)나노폴', 'corp_name_eng': 'NANOPOLYMER INC.', 'stock_name': '나노폴', 'stock_code': '', 'ceo_nm': '정  철  상', 'corp_cls': 'E', 'jurir_no': '1901110036639', 'bizr_no': '6088136150', 'adres': '경상남도 마산시 양덕2동 마산수출자유지역공단 974-7', 'hm_url': 'www.nanopol.com', 'ir_url': '', 'phn_no': '055-290-1901', 'fax_no': '055-299-9950', 'induty_code': '20202', 'est_dt': '19991029', 'acc_mt': '09'}

# %%
### 반복문 실행
for corp_code in code_list[18000:27000]:
    company_dict = load_data(corp_code)
    
    ### list 변경할것
    company_list_4.append(company_dict)

    # sleep으로 트래픽 휴식시간주기 
    time.sleep(0.1)

# %%
print(company_list_3[0])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00594484', 'corp_name': '주식회사뉴그린테크', 'corp_name_eng': 'NEWGREENTECH CO.,LTD', 'stock_name': '뉴그린테크', 'stock_code': '', 'ceo_nm': '문종철', 'corp_cls': 'E', 'jurir_no': '2201110025057', 'bizr_no': '6168125241', 'adres': '충청북도 청원군 오창면 성산리 15-1', 'hm_url': '', 'ir_url': '', 'phn_no': '043-217-6851', 'fax_no': '043-217-6853', 'induty_code': '29172', 'est_dt': '19990401', 'acc_mt': '12'}

# %%
len(company_list_1)
# Out:
# 9000

# %%
len(company_list_2)
# Out:
# 9000

# %%
len(company_list_4)
# Out:
# 9000

# %%
print(company_list_4[0])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00594484', 'corp_name': '주식회사뉴그린테크', 'corp_name_eng': 'NEWGREENTECH CO.,LTD', 'stock_name': '뉴그린테크', 'stock_code': '', 'ceo_nm': '문종철', 'corp_cls': 'E', 'jurir_no': '2201110025057', 'bizr_no': '6168125241', 'adres': '충청북도 청원군 오창면 성산리 15-1', 'hm_url': '', 'ir_url': '', 'phn_no': '043-217-6851', 'fax_no': '043-217-6853', 'induty_code': '29172', 'est_dt': '19990401', 'acc_mt': '12'}

# %%
len(company_list_5)
# Out:
# 9000

# %%
len(company_list_6)
# Out:
# 9000

# %%
len(company_list_7)
# Out:
# 9000

# %%
print(company_list_7[8999])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00445072', 'corp_name': '(주)탠디', 'corp_name_eng': 'TANDY . CO., LTD', 'stock_name': '탠디', 'stock_code': '', 'ceo_nm': '정기수', 'corp_cls': 'E', 'jurir_no': '1101111113268', 'bizr_no': '1128138114', 'adres': '서울특별시 관악구 봉천11동 1655-1', 'hm_url': 'www.tandy-e.co.kr', 'ir_url': '', 'phn_no': '02-885-8753', 'fax_no': '02-874-8448', 'induty_code': '15211', 'est_dt': '19941227', 'acc_mt': '12'}

# %%
len(company_list_8)
# Out:
# 9000

# %%
print(company_list_8[8999])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '01144019', 'corp_name': '주식회사 영수산업개발', 'corp_name_eng': 'YOUNGSOO DEVELOPMENT CO., LTD.', 'stock_name': '영수산업개발', 'stock_code': '', 'ceo_nm': '이정숙', 'corp_cls': 'E', 'jurir_no': '1801110925644', 'bizr_no': '6078615797', 'adres': '부산광역시 연제구 중앙대로 1094 (연산동, 금강빌딩5층)', 'hm_url': '', 'ir_url': '', 'phn_no': '0519618000', 'fax_no': '0519618001', 'induty_code': '6812', 'est_dt': '20140729', 'acc_mt': '12'}

# %%
len(company_list_9)
# Out:
# 9000

# %%
print(company_list_9[8999])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00126821', 'corp_name': '(주)삼안', 'corp_name_eng': 'Saman Corporation', 'stock_name': '삼안', 'stock_code': '', 'ceo_nm': '최동식', 'corp_cls': 'E', 'jurir_no': '1101110085517', 'bizr_no': '2118125425', 'adres': '경기도 과천시 별양상가3로 5 (별양동, 유니온빌딩) 6층', 'hm_url': 'www.samaneng.com', 'ir_url': '', 'phn_no': '02-6488-8000', 'fax_no': '02-6488-8080', 'induty_code': '72121', 'est_dt': '19671230', 'acc_mt': '12'}

# %%
len(company_list_10)
# Out:
# 8939

# %%
print(company_list_10[8938])
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00585963', 'corp_name': '지앤지인베스트 주식회사', 'corp_name_eng': 'GnG Invest co., Ltd.', 'stock_name': '지앤지인베스트', 'stock_code': '', 'ceo_nm': '선경래', 'corp_cls': 'E', 'jurir_no': '1101113315002', 'bizr_no': '2118771445', 'adres': '서울특별시 강남구 남부순환로 2736 (도곡동)', 'hm_url': '', 'ir_url': '', 'phn_no': '02-3460-4821', 'fax_no': '02-3460-4829', 'induty_code': '68112', 'est_dt': '20050930', 'acc_mt': '03'}

# %% [markdown]
# ### 데이터 저장

# %%
### pickle 모듈 import
import pickle

### pickle 모듈을 통해 list 저장
with open('company_4.txt','wb') as f:
       pickle.dump(company_list_4,f)

# %% [markdown]
# ### 기업 개황 통합

# %%
### 기업개황 통합하기
# 모든 기업개황이 담길 list
total_company_list=[]

# for문을 이용해 통합
for num in range(1,10):
    file_name = 'company_'+str(num)+'.txt'
    with open(file_name,'rb') as f:
        data=pickle.load(f)
        total_company_list=total_company_list + data
        
 # 통합 list 저장
 with open('total_company_list.txt','wb') as f:
       pickle.dump(total_company_list,f)

# %%
total_company_list = []

total_company_list += company_list_1
total_company_list += company_list_2
total_company_list += company_list_4
total_company_list += company_list_5
total_company_list += company_list_6
total_company_list += company_list_7
total_company_list += company_list_8
total_company_list += company_list_9
total_company_list += company_list_10

# %%
len(total_company_list)
# Out:
# 80939

# %% [markdown]
# ## 데이터프레임화 및 통합리스트 엑셀화

# %%
data = pd.DataFrame(total_company_list)

# %%
data.to_excel('기업개황.xlsx')

# %%
type(total_company_list[0])
# Out:
# dict

# %% [markdown]
# # -------------------------------------------

# %% [markdown]
# # 재무제표 크롤링

# %%
url = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=" + crtfc_key_1 + "&corp_code=00126380&bsns_year=2017&reprt_code=11011&fs_div=OFS"

# %%
print(code_list[30000])
# Out:
# 00299996

# %%
r = requests.get(url)
finance_data = r.json()

# %%
print(load_finance_data('00126380'))
# Out:
# {'status': '000', 'message': '정상', 'list': [{'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'ifrs_CurrentAssets', 'account_nm': '유동자산', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '70155189000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '69981128000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '67002055000000', 'ord': '1'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'ifrs_CashAndCashEquivalents', 'account_nm': '현금및현금성자산', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '2763768000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '3778371000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '3062960000000', 'ord': '2'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents', 'account_nm': '단기금융상품', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '25510064000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '30170656000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '27763589000000', 'ord': '3'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': '-표준계정코드 미사용-', 'account_nm': '단기매도가능금융자산', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '3021210000000', 'ord': '4'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'dart_ShortTermTradeReceivable', 'account_nm': '매출채권', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '27881777000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '23514012000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '20251464000000', 'ord': '5'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'dart_ShortTermOtherReceivables', 'account_nm': '미수금', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '2201402000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '2319782000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '2314823000000', 'ord': '6'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': '-표준계정코드 미사용-', 'account_nm': '선급금', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '1097598000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '814300000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '1105216000000', 'ord': '7'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': '-표준계정코드 미사용-', 'account_nm': '선급비용', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '2281179000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '2375520000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '1980305000000', 'ord': '8'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'ifrs_Inventories', 'account_nm': '재고자산', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '7837144000000', 'frmtrm_nm': '제 48 기', 'frmtrm_amount': '5981634000000', 'bfefrmtrm_nm': '제 47 기', 'bfefrmtrm_amount': '6578112000000', 'ord': '9'}, {'rcept_no': '20180402005019', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '00126380', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'dart_OtherCurrentAssets', 'account_nm': '기타유동자산', 'account_detail': '-', 'thstrm_nm': '제 49 기', 'thstrm_amount': '5822570000 ...

# %%
len(finance_list_1)
# Out:
# 9000

# %%
### 본인의 인증키 입력
crtfc_key_1 = "ab851319407812ac10d593dcb2fef51d0c944b66"
crtfc_key_2 = "f494a3020128060351c817cabf5b1b4a851e0737"
crtfc_key_3 = "5a79f1c6d673e00b0614c74e542b390ddd0b3542" 
crtfc_key_4 = "614f7fe579f14daf0ecb6aa38652677ab0576191"
crtfc_key_5 = "d4857d7491b5c47d494584350731c06dc7b66882" 
crtfc_key_6 = "bb7d92cbd78b6b67d156bef779a02e74bce661c4"
crtfc_key_7 = "a30987f4b05d0371f9f3d84c898efc698bbbc1e2"
crtfc_key_8 = "012be8cea16c0d414c5273f7422280f3f9905adf"
crtfc_key_9 = "ba2c91d2cc13f79700da1e0ed1542d2a37f18068"
crtfc_key_10 = "02c190bf4a27db86defd39afd0c48183dbff1d2c"
crtfc_key_11 = "a263608b5e4e9040a9de7ad1f0ff62808b29503d"
crtfc_key_12 = "c42daf7eaba42a0ed786b61e59240c58caa1d5d6"

# %%
### 재무제표 검색 함수 만들기
def load_finance_data(corp_code):
    
    ### 재무제표 요청 url
    url = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json?crtfc_key=" +crtfc_key_6+"&corp_code=" +corp_code + "&bsns_year=2019&reprt_code=11011&fs_div=OFS"    

    ### HTTP 요청
    r = requests.get(url)
     
    ### 요청한 데이터는 json형태이기 때문에 json으로 읽어줍니다.
    finance_data = r.json()

    ### 재무제표를 요청했을 때 재무제표에 대한 자료를 반환합니다.
    return finance_data

# %% [markdown]
# ## 반복문을 통한 데이터 수집

# %%
### 데이터를 담아둘 list 생성
finance_list_18_1 = [] # 0 ~ 9,000 (ㅇ)
finance_list_18_2 = [] # 9,000 ~ 18,000 
finance_list_18_3 = []# 18,000 ~ 27,000
finance_list_18_4 = []# 27,000~ 36,000 
finance_list_18_5 = [] # 36,000 ~ 45,000
finance_list_18_6 = [] # 45,000 ~ 54,000 
finance_list_18_7 = []  # 54,000 ~ 63,000
finance_list_18_8 = [] # 63,000 ~ 72,000 
finance_list_18_9 = []# 72,000 ~ 80,939 
finance_list_18_10 = [] 
finance_list_18_11 = []

# %%
### 데이터를 담아둘 list 생성
finance_list_19_1 = [] # 0 ~ 9,000 (ㅇ)
finance_list_19_2 = [] # 9,000 ~ 18,000 
finance_list_19_3 = []# 18,000 ~ 27,000
finance_list_19_4 = []# 27,000~ 36,000 
finance_list_19_5 = [] # 36,000 ~ 45,000
finance_list_19_6 = [] # 45,000 ~ 54,000 
finance_list_19_7 = []  # 54,000 ~ 63,000
finance_list_19_8 = [] # 63,000 ~ 72,000 
finance_list_19_9 = []# 72,000 ~ 80,939 
finance_list_19_10 = [] 
finance_list_19_11 = []

# %%
### 반복문 실행
for corp_code in code_list[72000:]:
    company_dict = load_finance_data(corp_code)
    
    ### list 변경할것
    
    if(company_dict["status"] != "013") :
        finance_list_19_9.append(company_dict)


    # sleep으로 트래픽 휴식시간주기 
    time.sleep(0.1)

# %%
# 2017년 
total_finance_list = []

total_finance_list += finance_list_2 # 1개 
total_finance_list += finance_list_5 # 3개
total_finance_list += finance_list_6 # 608개
total_finance_list += finance_list_7 # 327개
total_finance_list += finance_list_9 # 373개
total_finance_list += finance_list_10 # 574개

# %%
total_finance_list_17 = total_finance_list

# %%
len(total_finance_list_17)
# Out:
# 1886

# %%
# 2018년
total_finance_list_18 = []

total_finance_list_18 += finance_list_18_2 # 1개
total_finance_list_18 += finance_list_18_5 # 3개
total_finance_list_18 += finance_list_18_6 # 624개
total_finance_list_18 += finance_list_18_7 # 347개
total_finance_list_18 += finance_list_18_8 # 402개
total_finance_list_18 += finance_list_18_9 # 601개

# %%
len(total_finance_list_18)
# Out:
# 1978

# %%
# 2019년
total_finance_list_19 = []

total_finance_list_19 += finance_list_19_2 # 1개
total_finance_list_19 += finance_list_19_5 # 4개
total_finance_list_19 += finance_list_19_6 # 639개
total_finance_list_19 += finance_list_19_7 # 371개
total_finance_list_19 += finance_list_19_8 # 424개
total_finance_list_19 += finance_list_19_9 # 622개

# %%
finance_list_19_9[621]
# Out:
# {'status': '000',
#  'message': '정상',
#  'list': [{'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentAssets',
#    'account_nm': '유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '85351808471',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '58690302024',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '56235281227',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CashAndCashEquivalents',
#    'account_nm': '현금및현금성자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '18884696935',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '19741642179',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '24152782622',
#    'ord': '2'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_TradeAndOtherCurrentReceivables',
#    'account_nm': '매출채권 및 기타유동채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '26747341997',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '13052344092',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '17535586348',
#    'ord': '3'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Inventories',
#    'account_nm': '재고자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '24720027793',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '15910206884',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '12496020164',
#    'ord': '4'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentTaxAssets',
#    'account_nm': '당기법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '49822192',
#    'ord': '5'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherCurrentFinancialAssets',
#    'account_nm': '기타유동금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '14999741746',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '9986108869',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '2001069901',
#    'ord': '6'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentAssets',
#    'account_nm': '비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '78925939343',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '70086811214',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '54861015987',
#    'ord': '7'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentReceivablesGross',
#    'account_nm': '장기매출채권 및 기타비유동채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '75475526',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '46265526',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '104265526',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_PropertyPlantAndEquipment',
#    'account_nm': '유형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '36197651552',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '44195677964',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '28178562122',
#    'ord': '9'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_InvestmentProperty',
#    'account_nm': '투자부동산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '10737519001',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '7042774816',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '7096888439',
#    'ord': '10'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_IntangibleAssetsOtherThanGoodwill',
#    'account_nm': '무형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1749180122',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1151850030',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1861799786',
#    'ord': '11'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '관계기업투자자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '10000000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '11300000000',
#    'ord': '12'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_DeferredTaxAssets',
#    'account_nm': '이연법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '645638133',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '16834319',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '13'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherNoncurrentFinancialAssets',
#    'account_nm': '기타비유동금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '29520475009',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '7633408559',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6319500114',
#    'ord': '14'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Assets',
#    'account_nm': '자산총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '164277747814',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '128777113238',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '111096297214',
#    'ord': '15'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentLiabilities',
#    'account_nm': '유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '42631761938',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '26167372437',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '18097141714',
#    'ord': '17'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_TradeAndOtherCurrentPayables',
#    'account_nm': '매입채무 및 기타유동채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '23561331856',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11522189978',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '10953313162',
#    'ord': '18'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_ShorttermBorrowings',
#    'account_nm': '단기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '15000000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '13000000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '7000000000',
#    'ord': '19'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentPortionOfLongtermBorrowings',
#    'account_nm': '유동성장기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '500000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '500000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '20'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentTaxLiabilities',
#    'account_nm': '당기법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '3570430082',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1145182459',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '143828552',
#    'ord': '21'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentLiabilities',
#    'account_nm': '비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '3626111456',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '3253044244',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '3716596657',
#    'ord': '22'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentPayables',
#    'account_nm': '장기매입채무 및 기타비유동채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1044939420',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '545974694',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '435474694',
#    'ord': '23'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermBorrowingsGross',
#    'account_nm': '장기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '2000000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '2500000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '3000000000',
#    'ord': '24'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_PostemploymentBenefitObligations',
#    'account_nm': '퇴직급여부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '433858911',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '207069550',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '146305092',
#    'ord': '25'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_DeferredTaxLiabilities',
#    'account_nm': '이연법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '134816871',
#    'ord': '26'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherNoncurrentFinancialLiabilities',
#    'account_nm': '기타비유동금융부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '147313125',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '27'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Liabilities',
#    'account_nm': '부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '46257873394',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '29420416681',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '21813738371',
#    'ord': '28'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_IssuedCapital',
#    'account_nm': '자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '4898400000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '4898400000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '4898400000',
#    'ord': '30'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_SharePremium',
#    'account_nm': '주식발행초과금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '11545582831',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11545582831',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '11545582831',
#    'ord': '31'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_CapitalSurplus',
#    'account_nm': '자본잉여금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1609606411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1609606411',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1609606411',
#    'ord': '32'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_TreasuryShares',
#    'account_nm': '자기주식',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1339740375',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1339740375',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1339740375',
#    'ord': '33'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherComprehensiveIncomeLossAccumulatedAmount',
#    'account_nm': '기타포괄손익누계액',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-14586411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '241001556',
#    'ord': '34'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_RetainedEarnings',
#    'account_nm': '이익잉여금(결손금)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '101320611964',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '82642847690',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '72327708420',
#    'ord': '35'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '자본총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '118019874420',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '99356696557',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '89282558843',
#    'ord': '36'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_EquityAndLiabilities',
#    'account_nm': '자본과부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '164277747814',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '128777113238',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '111096297214',
#    'ord': '37'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_Revenue',
#    'account_nm': '수익(매출액)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '112750377665',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '54855376318',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '54279995081',
#    'ord': '0'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_CostOfSales',
#    'account_nm': '매출원가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '82519463439',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '38817766549',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '34899422768',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_GrossProfit',
#    'account_nm': '매출총이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '30230914226',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '16037609769',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '19380572313',
#    'ord': '2'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_TotalSellingGeneralAdministrativeExpenses',
#    'account_nm': '판매비와관리비',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '18953656808',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '17167852396',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '13496207325',
#    'ord': '3'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OperatingIncomeLoss',
#    'account_nm': '영업이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '11277257418',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-1130242627',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '5884364988',
#    'ord': '4'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherGains',
#    'account_nm': '기타수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '12306870394',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '13274547354',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '968190873',
#    'ord': '5'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherLosses',
#    'account_nm': '기타비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '717312086',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '89214011',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '51011754',
#    'ord': '6'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_FinanceIncome',
#    'account_nm': '금융수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1319515331',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '711203565',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '597117850',
#    'ord': '7'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_FinanceCosts',
#    'account_nm': '금융비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '292655218',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '287207211',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '288990187',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ProfitLossBeforeTax',
#    'account_nm': '법인세비용차감전순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '23893675839',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '12479087070',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '7109671770',
#    'ord': '9'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_IncomeTaxExpenseContinuingOperations',
#    'account_nm': '법인세비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '3596667675',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1301179126',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '414276683',
#    'ord': '10'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '20297008164',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11177907944',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6695395087',
#    'ord': '11'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_OtherComprehensiveIncome',
#    'account_nm': '기타포괄손익등',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-231045347',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-169124730',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '70074589',
#    'ord': '12'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '보험수리적손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-216458936',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-222427886',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1271580',
#    'ord': '13'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-14586411',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-241001556',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '68803009',
#    'ord': '14'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산처분손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '294304712',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '15'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ComprehensiveIncome',
#    'account_nm': '총포괄이익',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '20065962817',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11008783214',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6765469676',
#    'ord': '16'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_BasicEarningsLossPerShare',
#    'account_nm': '기본주당이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '2171',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1195',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '716',
#    'ord': '18'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInOperatingActivities',
#    'account_nm': '영업활동현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '2972310010',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '2551705543',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '7297429748',
#    'ord': '0'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_AdjustmentsForReconcileProfitLoss',
#    'account_nm': '영업으로부터 창출된 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '3950346867',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '2320989678',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '7551340510',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestReceivedClassifiedAsOperatingActivities',
#    'account_nm': '이자수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1039408973',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '776579878',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '382441868',
#    'ord': '2'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestPaidClassifiedAsOperatingActivities',
#    'account_nm': '이자지급',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '282538600',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '275070663',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '169091950',
#    'ord': '3'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_DividendsReceivedClassifiedAsOperatingActivities',
#    'account_nm': '배당금수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '150000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '150000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '572000',
#    'ord': '4'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_IncomeTaxesPaidRefundClassifiedAsOperatingActivities',
#    'account_nm': '법인세납부(환급)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1735057230',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '270943350',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '467832680',
#    'ord': '5'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInInvestingActivities',
#    'account_nm': '투자활동현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-4393592818',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-12164771366',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-12305031660',
#    'ord': '6'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfShortTermFinancialInstruments',
#    'account_nm': '단기금융상품의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '18976164384',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '22268724660',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6730643154',
#    'ord': '7'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '장기금융상품의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1970000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1003912880',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '종속기업투자자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '9'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '관계기업투자자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '2278666529',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '23586678000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '10'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능증권의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1000000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '58718026',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '11'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '20651900000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '4130910',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '2727273',
#    'ord': '12'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_DecreaseInGuaranteeDeposits',
#    'account_nm': '임차보증금의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '790000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '58000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '50000000',
#    'ord': '13'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfShortTermFinancialInstruments',
#    'account_nm': '단기금융상품의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '23989797261',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '30276083564',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '3959479453',
#    'ord': '14'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '단기대여금의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '10888940',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '15'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfLongTermFinancialInstruments',
#    'account_nm': '장기금융상품의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '14338266977',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '2391210992',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '419550480',
#    'ord': '16'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '관계기업투자자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '10000000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '17'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능증권의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '4537500000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '700000000',
#    'ord': '18'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '5695549493',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '16467752346',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '19'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '680000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '13979072154',
#    'ord': '20'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_IncreaseInGuaranteeDeposits',
#    'account_nm': '임차보증금의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '30000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '30300000',
#    'ord': '21'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInFinancingActivities',
#    'account_nm': '재무활동현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '564730169',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '5115354500',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '2305748150',
#    'ord': '22'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromShortTermBorrowings',
#    'account_nm': '단기차입금의 차입',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '2000000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '7000000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '3000000000',
#    'ord': '23'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_IncreaseInGuaranteeDepositsAsFinancialActivities',
#    'account_nm': '임대보증금의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '670000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '90000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '70000000',
#    'ord': '24'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_RepaymentsOfShortTermBorrowings',
#    'account_nm': '단기차입금의 상환',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1000000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '25'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '유동성장기부채 상환',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '500000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '26'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '리스부채의 상환',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '83301581',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '27'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_DecreaseInGuaranteeDepositsAsFinancialActivities',
#    'account_nm': '임대보증금의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '120000000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '40000000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '110000000',
#    'ord': '28'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_DividendsPaidClassifiedAsFinancingActivities',
#    'account_nm': '배당금지급',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1401968250',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '934645500',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '654251850',
#    'ord': '29'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_EffectOfExchangeRateChangesOnCashAndCashEquivalents',
#    'account_nm': '현금및현금성자산에 대한 환율변동효과',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-392605',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-3429120',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-84114037',
#    'ord': '30'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_IncreaseDecreaseInCashAndCashEquivalents',
#    'account_nm': '현금의 증가(감소)',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-856945244',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-4501140443',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-2785967799',
#    'ord': '31'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_CashAndCashEquivalentsAtBeginningOfPeriodCf',
#    'account_nm': '기초의 현금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '19741642179',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '24242782622',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '27028750421',
#    'ord': '32'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_CashAndCashEquivalentsAtEndOfPeriodCf',
#    'account_nm': '기말의 현금',
#    'account_detail': '-',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '18884696935',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '19741642179',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '24242782622',
#    'ord': '33'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '99356696557',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '89282558843',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '83171341017',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|기타자본잉여금',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1609606411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1609606411',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1609606411',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '241001556',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '172198547',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '82642847690',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '72327708420',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '66285293603',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|자기주식',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-1339740375',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-1339740375',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-1339740375',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '4898400000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '4898400000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '4898400000',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_EquityAtBeginningOfPeriod',
#    'account_nm': '기초자본',
#    'account_detail': '자본 [member]|주식발행초과금',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '11545582831',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11545582831',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '11545582831',
#    'ord': '1'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '회계정책의변경',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-816704',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '2'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '회계정책의변경',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-816704',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '2'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '20297008164',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11177907944',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6695395087',
#    'ord': '3'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '20297008164',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11177907944',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '6695395087',
#    'ord': '3'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-14586411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-241001556',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '68803009',
#    'ord': '4'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산평가손익',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-14586411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-241001556',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '68803009',
#    'ord': '4'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산처분손익',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '294304712',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '5'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '매도가능금융자산처분손익',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '294304712',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '',
#    'ord': '5'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '확정급여제도의 재측정요소',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-216458936',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-222427886',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1271580',
#    'ord': '6'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '확정급여제도의 재측정요소',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-216458936',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-222427886',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1271580',
#    'ord': '6'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '연차배당',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-1401968250',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-934645500',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-654251850',
#    'ord': '7'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '연차배당',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-1401968250',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-934645500',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-654251850',
#    'ord': '7'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '118019874420',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '99356696557',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '89282558843',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|기타자본잉여금',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '1609606411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '1609606411',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '1609606411',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-14586411',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '241001556',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '101320611964',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '82642847690',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '72327708420',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자기주식',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '-1339740375',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '-1339740375',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '-1339740375',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '4898400000',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '4898400000',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '4898400000',
#    'ord': '8'},
#   {'rcept_no': '20200330001092',
#    'reprt_code': '11011',
#    'bsns_year': '2019',
#    'corp_code': '00360674',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|주식발행초과금',
#    'thstrm_nm': '제 20 기',
#    'thstrm_amount': '11545582831',
#    'frmtrm_nm': '제 19 기',
#    'frmtrm_amount': '11545582831',
#    'bfefrmtrm_nm': '제 18 기',
#    'bfefrmtrm_amount': '11545582831',
#    'ord': '8'}]}

# %%
# 3개년치 통합
total_finance_all = []

total_finance_all += total_finance_list
total_finance_all += total_finance_list_18
total_finance_all += total_finance_list_19

# %%
len(total_finance_all)
# Out:
# 5925

# %%
# 조회되지 않은 기업 걸러내기
while(len(finance_list_7) > 327) :
#cnt = 0
    for company in finance_list_7 :
        if(company["status"] != '000'):
            finance_list_7.remove(company)
        #cnt += 1
#print(cnt)

# %%
# Out:
# True

# %% [markdown]
# ## 모델링 구조에 맞게 데이터 가공하기

# %% [markdown]
# < 공통 >
# corp_code, thstrm_nm(회차), 등록일
#
# < 포괄손익계산서 >
# 수익(매출액), 영업이익(손실), 당기순이익(손실)
#
# < 재무상태표 >
# 유동자산,비유동자산, 자산총계, 유동부채, 비유동부채, 부채총계, 자본금, 이익잉여금(결손금), 자본총계
#
# < 현금흐름표 >
# 영업활동현금흐름, 투자활동현금흐름, 재무활동현금흐름

# %%
company = finance_list_7[2]  # 리스트에 들어있는 회사 하나 추출 (dict)
companyFin = company['list'] # 세가지 key값중 재무제표 list 키 추출 
print(companyFin[0]) # list 키의 첫번째 dict 추출
# Out:
# {'rcept_no': '20180329000878', 'reprt_code': '11011', 'bsns_year': '2017', 'corp_code': '01196313', 'sj_div': 'BS', 'sj_nm': '재무상태표', 'account_id': 'ifrs_CurrentAssets', 'account_nm': '유동자산', 'account_detail': '-', 'thstrm_nm': '제 1 기', 'thstrm_amount': '5900991531', 'ord': '1'}

# %%
# DB에 손익계산서, 재무상태표, 현금 흐름표로 나뉘어져있으므로 각각의 리스트와 딕셔너리를 만든다.
cash_flow_list = []
fs_status_list = []
icm_stmt_list = []

cash_flow_dict = {}
fs_status_dict = {}
icm_stmt_dict = {}

# %% [markdown]
# ### 손익계산서

# %%
for org_dict in total_finance_all:
    finc_list = org_dict["list"]
    # 각 딕셔너리마다 기업 코드, 회차, 등록일 key 추가 
    icm_stmt_dict["기업코드"] = (finc_list[0])["corp_code"]
    icm_stmt_dict["회차"] = (finc_list[0])["thstrm_nm"]
    icm_stmt_dict["등록일"] = ((finc_list[0])["rcept_no"])[0:8]
    for finc_dict in finc_list:
        if(finc_dict["sj_nm"] == '포괄손익계산서'):
            # 필요한 항목만 골라 넣는다. 
            if(finc_dict["account_nm"] == '수익(매출액)') or (finc_dict["account_nm"] == '영업이익(손실)') or (finc_dict["account_nm"] == '당기순이익(손실)'):  
                column = finc_dict["account_nm"]
                icm_stmt_dict[column] = finc_dict["thstrm_amount"]
    icm_stmt_list.append(icm_stmt_dict) # 한 회사의 손익계산서 딕셔너리 완성 후 리스트에 넣기 
    icm_stmt_dict = {} # 딕셔너리 초기화

# %%
icm_stmt_data = pd.DataFrame(icm_stmt_list)

# %%
icm_stmt_data.head(10)
# Out:
#        기업코드      회차       등록일   수익(매출액)     영업이익(손실)      당기순이익(손실)
# 0  00956028  제 16 기  20180420  24347218       120381       -1629679
# 1  01165739   제 3 기  20180430       NaN     -3982045      -13864646
# 2  00171636  제 53 기  20180402       NaN  14952676720  -143685542254
# 3  00147772  제 49 기  20180330       NaN          NaN            NaN
# 4  00273110  제 29 기  20180402       NaN  -8455346598   -10797600612
# 5  00159500  제 55 기  20180402       NaN          NaN            NaN
# 6  00105466  제 29 기  20180402       NaN          NaN    22483322690
# 7  00347716  제 19 기  20180402       NaN    283563642      622165934
# 8  00112165  제 42 기  20180402       NaN          NaN            NaN
# 9  00103510  제 40 기  20180402       NaN          NaN            NaN

# %%
icm_stmt_data.sort_values('기업코드')
# Out:
#           기업코드      회차       등록일      수익(매출액)      영업이익(손실)     당기순이익(손실)
# 58    00100601  제 43 기  20180402  83113028513   -5421114014   -6291307194
# 1944  00100601  제 44 기  20190401  85905365198     532248075    1977523940
# 3923  00100601  제 45 기  20200406  42549621578  -17150531429  -33460764640
# 2004  00100939  제 67 기  20190401          NaN   -1028785211           NaN
# 117   00100939  제 66 기  20181231          NaN           NaN   16654666449
# ...        ...     ...       ...          ...           ...           ...
# 4905  01391033   제 1 기  20200228          NaN   -1694707813   -1671751947
# 4881  01395279   제 1 기  20200330          NaN     -64574620     -43125389
# 5741  01412725   제 1 기  20200330          NaN           NaN           NaN
# 5313  01412822   제 1 기  20200330          NaN           NaN   15330997672
# 4394  01416457   제 1 기  20200325          NaN      -4535900      -8102834
#
# [5925 rows x 6 columns]

# %%
icm_stmt_data.to_csv('손익계산서.csv', encoding='utf-8-sig')

# %% [markdown]
# ### 현금흐름표

# %%
for org_dict in total_finance_all:
    finc_list = org_dict["list"]
    cash_flow_dict["기업코드"] = (finc_list[0])["corp_code"]
    cash_flow_dict["회차"] = (finc_list[0])["thstrm_nm"]
    cash_flow_dict["등록일"] = ((finc_list[0])["rcept_no"])[0:8]
    for finc_dict in finc_list:
        if(finc_dict["sj_nm"] == '현금흐름표'):
            if(finc_dict["account_nm"] == '영업활동현금흐름') or (finc_dict["account_nm"] == '투자활동현금흐름') or (finc_dict["account_nm"] == '재무활동현금흐름'):  
                column = finc_dict["account_nm"]
                cash_flow_dict[column] = finc_dict["thstrm_amount"]
    cash_flow_list.append(cash_flow_dict) # 한 회사의 손익계산서 딕셔너리 완성 후 리스트에 넣기 
    cash_flow_dict = {} # 딕셔너리 초기화

# %%
cash_flow_data = pd.DataFrame(cash_flow_list)
cash_flow_data.head(10)
# Out:
#        기업코드      회차       등록일      영업활동현금흐름      투자활동현금흐름      재무활동현금흐름
# 0  00956028  제 16 기  20180420       1161698     -15785668        830508
# 1  01165739   제 3 기  20180430      -4598219     -13011920       5795985
# 2  00171636  제 53 기  20180402    9117278973   17226706791  -20594094048
# 3  00147772  제 49 기  20180330           NaN           NaN           NaN
# 4  00273110  제 29 기  20180402   -7277233468   -6512408018     -11193520
# 5  00159500  제 55 기  20180402  -11091184217    -562731217    6905000000
# 6  00105466  제 29 기  20180402  102568543327   60271820095  -50033249894
# 7  00347716  제 19 기  20180402     172079738    -793571120   -3417278080
# 8  00112165  제 42 기  20180402   37716905103  -94174826177   55604513647
# 9  00103510  제 40 기  20180402           NaN           NaN           NaN

# %%
cash_flow_data.sort_values('기업코드')
# Out:
#           기업코드      회차       등록일      영업활동현금흐름      투자활동현금흐름     재무활동현금흐름
# 58    00100601  제 43 기  20180402   -4605588268     484043205   4943754181
# 1944  00100601  제 44 기  20190401  -10047711148   -2019807782  17827827469
# 3923  00100601  제 45 기  20200406    7013797609  -14691821920  -8116984868
# 2004  00100939  제 67 기  20190401           NaN           NaN          NaN
# 117   00100939  제 66 기  20181231           NaN           NaN          NaN
# ...        ...     ...       ...           ...           ...          ...
# 4905  01391033   제 1 기  20200228   -1054550728  -88500000000  91715654000
# 4881  01395279   제 1 기  20200330     -62789181   -8000000000   9028840000
# 5741  01412725   제 1 기  20200330  121737503688  -22831955360    407440864
# 5313  01412822   제 1 기  20200330           NaN           NaN          NaN
# 4394  01416457   제 1 기  20200325      -4327212             0   1794117960
#
# [5925 rows x 6 columns]

# %%
cash_flow_data.to_csv('현금흐름표.csv', encoding='utf-8-sig')

# %% [markdown]
# ### 재무상태표

# %%
for org_dict in total_finance_all:
    finc_list = org_dict["list"]
    fs_status_dict["기업코드"] = (finc_list[0])["corp_code"]
    fs_status_dict["회차"] = (finc_list[0])["thstrm_nm"]
    fs_status_dict["등록일"] = ((finc_list[0])["rcept_no"])[0:8]
    for finc_dict in finc_list:
        if(finc_dict["sj_nm"] == '재무상태표'):
            if(finc_dict["account_nm"] == '유동자산') or (finc_dict["account_nm"] == '비유동자산') or (finc_dict["account_nm"] == '자산총계') or (finc_dict["account_nm"] == '유동부채') or (finc_dict["account_nm"] == '비유동부채') or (finc_dict["account_nm"] == '부채총계') or (finc_dict["account_nm"] == '자본금') or (finc_dict["account_nm"] == '이익잉여금(결손금)') or (finc_dict["account_nm"] == '자본총계'):
                column = finc_dict["account_nm"]
                fs_status_dict[column] = finc_dict["thstrm_amount"]
    fs_status_list.append(fs_status_dict) # 한 회사의 손익계산서 딕셔너리 완성 후 리스트에 넣기 
    fs_status_dict = {} # 딕셔너리 초기화

# %%
fs_status_data = pd.DataFrame(fs_status_list)
fs_status_data.head(10)
# Out:
#        기업코드      회차       등록일          유동자산         비유동자산          자산총계  \
# 0  00956028  제 16 기  20180420      23053799      55270950      78324749
# 1  01165739   제 3 기  20180430      39187249      27230058      66417307
# 2  00171636  제 53 기  20180402    8656683896  452754909587  461411593483
# 3  00147772  제 49 기  20180330           NaN           NaN   62899736059
# 4  00273110  제 29 기  20180402   11484849985   24192533734   35677383719
# 5  00159500  제 55 기  20180402   93977947500  136820743192  230798690692
# 6  00105466  제 29 기  20180402  682207183358  259475957580  941683140938
# 7  00347716  제 19 기  20180402   13130043454   11248989425   24379032879
# 8  00112165  제 42 기  20180402  189557406829  349216102055  538773508884
# 9  00103510  제 40 기  20180402  114185760792  196632294458  310818055250
#
#            유동부채         비유동부채          부채총계           자본금    이익잉여금(결손금)  \
# 0      15314213      11512077      26826290       1366450      17919915
# 1      11385513             0      11385513       4966967     -13005260
# 2    9105276838   22038461788   31143738626  231799355000   81399817430
# 3           NaN           NaN   28140205074           NaN           NaN
# 4    2063068823    5250465188    7313534011   13303870000  -10775638709
# 5   76077411069   40337889907  116415300976    5475000000           NaN
# 6  434557205516  168853599677  603410805193  107000000000           NaN
# 7    9500585037    1409592117   10910177154   10493313500   -4623660041
# 8  294703583409   97564190543  392267773952   11233705000   70911252555
# 9  138650202421   24074894232  162725096653    7580064000           NaN
#
#            자본총계
# 0      51498459
# 1      55031794
# 2  430267854857
# 3   34759530985
# 4   28363849708
# 5  114383389716
# 6  338272335745
# 7   13468855725
# 8  146505734932
# 9  148092958597

# %%
len(finance_list_7)
# Out:
# 327

# %%
fs_status_data.to_csv('재무상태표.csv', encoding='utf-8-sig')

# %%
fs_status_data.sort_values('기업코드').head(20)
# Out:
#           기업코드      회차       등록일          유동자산         비유동자산          자산총계  \
# 58    00100601  제 43 기  20180402   66557787965   21223628476   87781416441
# 1944  00100601  제 44 기  20190401   70097813693   19521936702   89619750395
# 3923  00100601  제 45 기  20200406   30346448966   24759582846   55106031812
# 2004  00100939  제 67 기  20190401  143360831465  258091231946  401452063411
# 117   00100939  제 66 기  20181231  194534019874  212098304072  406632323946
# 3983  00100939  제 68 기  20200330  129428124035  267164931544  396593055579
# 253   00101044  제 59 기  20180911   63258757054   98164837818  161423594872
# 4123  00101044  제 61 기  20200327  157807887088  126620076361  284427963449
# 2143  00101044  제 60 기  20190626   82559424648  128678072487  211237497135
# 744   00101220  제 64 기  20180402   83344061903  226633768676  309977830579
# 2656  00101220  제 65 기  20190401   64149641523  221833135405  285982776928
# 4660  00101220  제 66 기  20200330   57702368500  252516469593  310218838093
# 748   00101433  제 61 기  20180330  114661595726  154305414448  268967010174
# 2660  00101433  제 62 기  20190403  124295853847  160736019561  285031873408
# 4664  00101433  제 63 기  20200330  138697200573  158499887216  297197087789
# 2625  00101488  제 46 기  20190329  209454207589  231059453221  440513660810
# 715   00101488  제 45 기  20180330  175839342251  215561149406  391400491657
# 4627  00101488  제 47 기  20200327  214093728702  247513288433  461607017135
# 317   00101549  제 42 기  20180608  106211952674  142873446023  249085398697
# 4186  00101549  제 44 기  20200327  140715153277  136460468844  277175622121
#
#               유동부채        비유동부채          부채총계           자본금    이익잉여금(결손금)  \
# 58     36681992542   3982403996   40664396538    7626515000   23551833834
# 1944   40299771673     33624445   40333396118    7683448000   26310724594
# 3923   27565064738   4636933544   32201998282    8721837000   -7611775894
# 2004   48445522755   9701443840   58146966595           NaN           NaN
# 117    55319514631   8855556418   64175071049           NaN           NaN
# 3983   47662141406   9987893012   57650034418           NaN           NaN
# 253    31534275686  45301743760   76836019446   42314464000  -19814399224
# 4123   33842453248   3656633241   37499086489  120829164000  -40835558690
# 2143   60079502045   3019504196   63099006241   53941097000  -34660849002
# 744   110708137833   9087534736  119795672569   64175290000  106342753131
# 2656   93169342153   9178349294  102347691447   64585875000           NaN
# 4660  118599612338  15443714075  134043326413   67374405000           NaN
# 748    78430974112   7576878063   86007852175   10845875000  126991395240
# 2660   86896477184  11068709644   97965186828   10845875000  141315028244
# 4664   80682497142  25621976832  106304473974   10845875000  143910722431
# 2625  191253919990   8903790166  200157710156           NaN  204400341604
# 715   159637321715   9734676059  169371997774           NaN  184187688556
# 4627  183748685291  23298810756  207047496047           NaN  219052792728
# 317    27146627892   2224902935   29371530827   13575000000  212273780729
# 4186   23116722718  28557292893   51674015611   13575000000  217601682296
#
#               자본총계
# 58     47117019903
# 1944   49286354277
# 3923   22904033530
# 2004  343305096816
# 117   342457252897
# 3983  338943021161
# 253    84587575426
# 4123  246928876960
# 2143  148138490894
# 744   190182158010
# 2656  183635085481
# 4660  176175511680
# 748   182959157999
# 2660  187066686580
# 4664  190892613815
# 2625  240355950654
# 715   222028493883
# 4627  254559521088
# 317   219713867870
# 4186  225501606510

# %% [markdown]
# # --------------------------------------------------------

# %% [markdown]
# # 기업 개황 데이터 불러와 정제

# %%
import pandas as pd

# %%
corpData = pd.read_excel('/Users/linakim/Desktop/최종프로젝트/기업개황.xlsx', '정제후')

# %%
corpData.head(3)
# Out:
#    Unnamed: 0  corp_code  corp_name                  corp_name_eng ceo_nm  \
# 0           0     434003      (주)다코               Daco corporation    김상규
# 1           1     434456    일산약품(주)  ILSAN PHARMACEUTICAL CO.,LTD.    이광선
# 2           2     430964  굿앤엘에스주식회사             Good & LS Co.,Ltd.    정진형
#
#   corp_cls       jurir_no     bizr_no                adres hm_url ir_url  \
# 0        E  1615110021778  3128134722  충청남도 천안시 청당동 419-12     없음    NaN
# 1        E  1412110004641  2248105027       강원도 원주시 원동 303    NaN    NaN
# 2        E  1101112672875  1048177488   서울특별시 중구 태평로2가 120    NaN    NaN
#
#          phn_no        fax_no induty_code      est_dt
# 0  041-565-1800  041-563-6808       25931  19970611.0
# 1  033-763-7535  033-763-6433       21101  19910615.0
# 2  02-6263-8185           NaN       64999  20021213.0
